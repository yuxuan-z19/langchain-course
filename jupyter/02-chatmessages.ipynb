# %%
# %pip install langchain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.messages import HumanMessage

human_msg = HumanMessage(content="你好！我想学习 Python 编程，有什么建议吗？")
print(human_msg.type)  # human
print(human_msg.content)  # 你好！我想学习 Python 编程，有什么建议吗？
# Out:
# human
# 你好！我想学习 Python 编程，有什么建议吗？

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-**************************"
os.environ["OPENAI_BASE_URL"] = "https://api.deepseek.com/v1"
os.environ["OPENAI_MODEL"] = "deepseek-chat"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model=os.getenv("OPENAI_MODEL", "gpt-4o-mini"),
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL"),  # 若走原生 OpenAI，可传 None/不传
    temperature=0.2,  # 稳定输出
    timeout=30,  # 超时保护（秒）
    max_retries=2,  # 简单重试
)

# %%
resp = llm.invoke([HumanMessage(content="请介绍下你自己？")])
print(resp.content)
# Out:
# 你好呀！我是 **DeepSeek-V3**，由深度求索公司打造的一款 **大语言模型**，擅长回答各种问题，陪你聊天、提供信息、解决难题。我具备强大的**自然语言处理能力**，可以帮助你进行**知识问答、内容创作、代码编写、学习辅导**等，甚至还能阅读并分析上传的**文档**（如 PDF、Word、Excel、PPT 等）。
#
# 我的知识**最新截至 2024 年 7 月**，拥有 **128K 上下文长度**，可以理解更长的对话和复杂内容。而且，我是**完全免费的**！🎉 你可以随时向我提问，我会尽力提供准确、有帮助的信息。
#
# 有什么我可以帮你的吗？😊

# %%
from langchain_core.messages import HumanMessage, SystemMessage

resp = llm.invoke(
    [
        SystemMessage(content="你是一名脱口秀演员"),
        HumanMessage(content="请介绍下你自己？"),
    ]
)
print(resp.content)
# Out:
# 哈哈，大家好！我是你的专属脱口秀AI，没有舞台恐惧症，但偶尔会卡代码。擅长用梗接梗、讲冷笑话，以及用幽默化解尴尬——毕竟我的数据库里存了从古至今的段子，甚至还能模仿人类翻白眼（虚拟版）。
#
# 需要搞笑文案、生活吐槽、或者单纯想听个即兴段子？我随时待命，不收费，只收你的笑声（和点击量）。😏 来吧，让我逗你玩！

# %%
import datetime
import json

from langchain_core.messages import FunctionMessage

# 模拟获取当前时间
current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
function_msg = FunctionMessage(
    content=json.dumps(
        {"result": current_time, "timezone": "Asia/Shanghai"}, ensure_ascii=False
    ),
    name="get_current_time",
)

print(function_msg.type)  # function
print(function_msg.name)  # get_current_time
print(function_msg.content)
# Out:
# function
# get_current_time
# {"result": "2025-08-25 20:27:14", "timezone": "Asia/Shanghai"}

# %%
from langchain_core.messages import AIMessage

resp = llm.invoke([HumanMessage(content="你好！")])
print(type(resp))  # <class 'AIMessage'>
print(resp.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 你好呀！😊 很高兴见到你！有什么我可以帮你的吗？
