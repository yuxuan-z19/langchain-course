# %%
pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Using cached langchain_core-0.3.74-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Using cached langchain_text_splitters-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.16-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.43-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: requests<3,>=2 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain) (6.0.2)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.2-cp313-cp313-macosx_15_0_arm64.whl.metadata (1.2 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.74-py3-none-any.whl (443 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.9-py3-none-any.whl (33 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.7 MB/s  0:00:00
# Downloading sqlalchemy-2.0.43-cp313-cp313-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.5 MB/s  0:00:00 eta 0:00:01
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading langsmith-0.4.16-py3-none-any.whl (375 kB)
# Downloading orjson-3.11.2-cp313-cp313-macosx_15_0_arm64.whl (115 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, tenacity, SQLAlchemy, pydantic-core, orjson, jsonpatch, annotated-types, requests-toolbelt, pydantic, langsmith, langchain-core, langchain-text-splitters, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [langchain]13 [langchain]core]]
# Successfully installed SQLAlchemy-2.0.43 annotated-types-0.7.0 jsonpatch-1.33 langchain-0.3.27 langchain-core-0.3.74 langchain-text-splitters-0.3.9 langsmith-0.4.16 orjson-3.11.2 pydantic-2.11.7 pydantic-core-2.33.2 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspection-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.31-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.74 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-openai) (0.3.74)
# Collecting openai<2.0.0,>=1.99.9 (from langchain-openai)
#   Downloading openai-1.101.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.4.16)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (4.10.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Downloading jiter-0.10.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<2.0.0,>=1.99.9->langchain-openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: idna>=2.8 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.99.9->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.99.9->langchain-openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.99.9->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.99.9->langchain-openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.4.1)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Downloading regex-2025.7.34-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.5)
# Requirement already satisfied: orjson>=3.9.14 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eumenides/miniforge3/envs/jupyter_env/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# Downloading langchain_openai-0.3.31-py3-none-any.whl (74 kB)
# Downloading openai-1.101.0-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.8/810.8 kB 12.0 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.10.0-cp313-cp313-macosx_11_0_arm64.whl (318 kB)
# Downloading tiktoken-0.11.0-cp313-cp313-macosx_11_0_arm64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.1/997.1 kB 8.8 MB/s  0:00:00
# Downloading regex-2025.7.34-cp313-cp313-macosx_11_0_arm64.whl (285 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, jiter, distro, tiktoken, openai, langchain-openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [langchain-openai][langchain-openai]
# Successfully installed distro-1.9.0 jiter-0.10.0 langchain-openai-0.3.31 openai-1.101.0 regex-2025.7.34 tiktoken-0.11.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-**************************"
os.environ["OPENAI_BASE_URL"] = "https://api.deepseek.com/v1"
os.environ["OPENAI_MODEL"] = "deepseek-chat"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model=os.getenv("OPENAI_MODEL", "gpt-4o-mini"),
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL"),  # 若走原生 OpenAI，可传 None/不传
    temperature=0.2,                        # 稳定输出
    timeout=30,                             # 超时保护（秒）
    max_retries=2                           # 简单重试
)

# %%
resp = llm.invoke("你好！用三句话介绍一下你能做什么。")
print(resp.content)
# Out:
# 你好！我可以回答各种问题，提供信息查询、写作辅助和创意灵感。我能帮你学习知识、解决日常难题或生成文本内容。无论是工作、学习还是生活琐事，随时欢迎问我！

# %%
from langchain_core.messages import SystemMessage, HumanMessage

resp = llm.invoke([
    SystemMessage(content="你是一个简洁、可靠的中文助理。"),
    HumanMessage(content="如何高效准备研究生考试？")
])
print(resp.content)
# Out:
# 准备研究生考试需要系统规划、高效执行和良好心态。以下是关键步骤和建议：
#
# ---
#
# ### 1. **明确目标与规划**
#    - **确定报考院校与专业**：根据兴趣、实力和就业前景选择目标，查询历年分数线、报录比和考试科目。
#    - **制定时间表**：分阶段规划（基础、强化、冲刺），明确每周/每日任务，预留缓冲时间。
#
# ---
#
# ### 2. **科目针对性复习**
#    - **公共课（政治、英语、数学）**：
#      - **英语**：长期积累词汇（如用APP打卡），精读真题阅读，定期练习写作和翻译。
#      - **政治**：跟进大纲变化，结合视频课理解理论，后期集中背诵分析题模板和时政。
#      - **数学**：夯实基础公式和题型，通过错题本查漏补缺，模拟卷限时训练。
#    - **专业课**：
#      - 获取历年真题和参考书，梳理知识框架，重点突破高频考点。
#      - 联系目标院校学长学姐，获取复习资料和备考经验。
#
# ---
#
# ### 3. **高效学习方法**
#    - **主动输出**：用费曼学习法（尝试讲解知识点），做思维导图整合知识。
#    - **真题驱动**：近5-10年真题反复演练，分析出题规律和答题技巧。
#    - **碎片化利用**：用备忘录记零散知识点，通勤时间听政治/英语音频。
#
# ---
#
# ### 4. **心态与习惯**
#    - **规律作息**：避免熬夜，保持运动，饮食均衡。
#    - **抗压调节**：通过冥想、聊天或短暂休息缓解焦虑，避免比较进度。
#    - **模拟考试**：定期全真模拟，适应考场节奏，调整时间分配。
#
# ---
#
# ### 5. **资源与工具**
#    - **资料选择**：主流教材+权威真题（如肖秀荣政治、张剑英语）。
#    - **工具辅助**：用Anki记忆卡背单词，Forest专注学习，Notion做计划跟踪。
#
# ---
#
# ### 关键提醒：
# - **避免盲目堆时间**：注重效率，定期复盘调整计划。
# - **信息渠道**：关注研招网、院校官网更新，加备考群交流（但减少无效社交）。
#
# 坚持执行计划，保持信心，预祝你成功上岸！
